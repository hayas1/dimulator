# %%
from dimulator.algorithms.bfstree import animate_breadth_first_tree, save_bfs_as_gif
from dimulator.algorithms.apsp import animate_all_pair_shortest_path, save_apsp_as_gif
from dimulator.algorithms.apsp1t import animate_all_pair_shortest_path_1token, save_apsp_1token_as_gif
from dimulator.algorithms.color_reduce import animate_color_reduce, save_color_reduce_as_gif, ColorReduceNode
from dimulator.algorithms.coloring import animate_coloring, save_coloring_as_gif
from dimulator.algorithms.mds_approx import animate_minimum_dominating_set_approx, save_msd_approx_as_gif, animate_mds_rounding, save_msd_rounding_as_gif

import os
import matplotlib.pyplot as plt
from matplotlib.animation import PillowWriter
from matplotlib import rc

from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')    # to reduce matplotlib warning

# %%
# save_bfs_as_gif(n=15, frames=200)
# save_apsp_as_gif(n=15, frames=500)
# save_apsp_1token_gif(n=15)
# save_color_reduce_as_gif(n=20, frames=450)
# save_coloring_as_gif(n=16, frames=1500)
# save_msd_approx_as_gif(n=20, frames=650)
save_msd_rounding_as_gif(n=20, frames=100)
# Out:
# MovieWriter ffmpeg unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.
# the algorithm terminated successfully
# C:\Users\R\AppData\Local\Programs\Python\Python37-32\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# C:\Users\R\AppData\Local\Programs\Python\Python37-32\lib\site-packages\networkx\drawing\nx_pylab.py:585: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   and cb.iterable(edge_color) \
